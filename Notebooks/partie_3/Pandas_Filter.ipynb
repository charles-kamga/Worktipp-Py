# %%
import pandas as p
from random import randint as r


columns = ['nom','age','genre','enseinte','fume']
m_noms = ['Max','Majid','Mark','Moeses','Mirza']
f_noms = ['Johana','Jalila','Judy','Jawaher','Jasmina','Jiji','Jala']

data = []
row = []
age = 0
for i in range(1,10000):
    gender = r(0,1)
    if gender == 0:
        age = r(15,70)
        row = [m_noms[r(0,4)],age,'Male',0,r(0,1)]
    elif gender == 1:
        age = r(15,70)
        if int(age)>37:
            row = [f_noms[r(0,6)],age,'Female',0,r(0,1)]
        else:
            row = [f_noms[r(0,6)],age,'Female',r(0,1),r(0,1)]
    data.append(row)

df = p.DataFrame(data,columns=columns)
df
# Out:
#           nom  age   genre  enseinte  fume
# 0        Judy   33  Female         0     0
# 1      Johana   65  Female         0     0
# 2       Majid   59    Male         0     0
# 3      Moeses   39    Male         0     1
# 4        Jiji   16  Female         0     1
# 5     Jawaher   40  Female         0     1
# 6        Jiji   56  Female         0     1
# 7     Jasmina   37  Female         0     0
# 8        Jala   15  Female         0     1
# 9        Jala   40  Female         0     1
# 10     Johana   17  Female         1     1
# 11      Mirza   28    Male         0     0
# 12    Jasmina   45  Female         0     1
# 13       Mark   46    Male         0     0
# 14       Jiji   23  Female         0     1
# 15       Judy   16  Female         0     1
# 16    Jasmina   69  Female         0     0
# 17       Judy   61  Female         0     1
# 18    Jasmina   47  Female         0     1
# 19     Jalila   48  Female         0     0
# 20      Majid   33    Male         0     0
# ...

# %%
df.shape
# Out:
# (9999, 5)

# %%
df_female = df[df.genre=='Female']
df_female
# Out:
#           nom  age   genre  enseinte  fume
# 0        Judy   33  Female         0     0
# 1      Johana   65  Female         0     0
# 4        Jiji   16  Female         0     1
# 5     Jawaher   40  Female         0     1
# 6        Jiji   56  Female         0     1
# 7     Jasmina   37  Female         0     0
# 8        Jala   15  Female         0     1
# 9        Jala   40  Female         0     1
# 10     Johana   17  Female         1     1
# 12    Jasmina   45  Female         0     1
# 14       Jiji   23  Female         0     1
# 15       Judy   16  Female         0     1
# 16    Jasmina   69  Female         0     0
# 17       Judy   61  Female         0     1
# 18    Jasmina   47  Female         0     1
# 19     Jalila   48  Female         0     0
# 21       Judy   24  Female         1     1
# 22     Johana   68  Female         0     0
# 23     Jalila   40  Female         0     1
# 26    Jasmina   24  Female         1     0
# 28    Jasmina   27  Female         0     1
# ...

# %%
df_female.shape
# Out:
# (4979, 5)

# %%
df_female_37 = df.query('genre==\'Female\' & age <=37')

# %%
df_female_37
# Out:
#           nom  age   genre  enseinte  fume
# 0        Judy   33  Female         0     0
# 4        Jiji   16  Female         0     1
# 7     Jasmina   37  Female         0     0
# 8        Jala   15  Female         0     1
# 10     Johana   17  Female         1     1
# 14       Jiji   23  Female         0     1
# 15       Judy   16  Female         0     1
# 21       Judy   24  Female         1     1
# 26    Jasmina   24  Female         1     0
# 28    Jasmina   27  Female         0     1
# 33    Jawaher   35  Female         0     1
# 40    Jasmina   36  Female         1     0
# 41     Jalila   24  Female         1     0
# 45    Jawaher   29  Female         0     0
# 47     Johana   36  Female         1     1
# 58    Jasmina   19  Female         0     0
# 59    Jawaher   20  Female         0     0
# 73       Jala   21  Female         1     1
# 75       Jiji   22  Female         1     0
# 78       Jiji   17  Female         0     1
# 79    Jasmina   34  Female         1     1
# ...

# %%
df_female_37.shape
# Out:
# (2039, 5)

# %%
df_female_37_ens_fume = df.query('genre==\'Female\' & age <=37 & enseinte==1 & fume==1')

# %%
df_female_37_ens_fume
# Out:
#           nom  age   genre  enseinte  fume
# 10     Johana   17  Female         1     1
# 21       Judy   24  Female         1     1
# 47     Johana   36  Female         1     1
# 73       Jala   21  Female         1     1
# 79    Jasmina   34  Female         1     1
# 81       Jiji   33  Female         1     1
# 90       Jala   30  Female         1     1
# 100   Jawaher   17  Female         1     1
# 108      Jiji   23  Female         1     1
# 131      Judy   18  Female         1     1
# 170    Jalila   33  Female         1     1
# 191      Judy   31  Female         1     1
# 231    Johana   15  Female         1     1
# 285      Jiji   17  Female         1     1
# 291    Jalila   32  Female         1     1
# 329      Judy   20  Female         1     1
# 333   Jasmina   21  Female         1     1
# 351      Judy   18  Female         1     1
# 363    Jalila   21  Female         1     1
# 370    Jalila   26  Female         1     1
# 374      Judy   32  Female         1     1
# ...

# %%
df_female_37_ens_fume.shape
# Out:
# (496, 5)

# %%
df1 = df_female_37_ens_fume[['nom','age']]

# %%
df1
# Out:
#           nom  age
# 10     Johana   17
# 21       Judy   24
# 47     Johana   36
# 73       Jala   21
# 79    Jasmina   34
# 81       Jiji   33
# 90       Jala   30
# 100   Jawaher   17
# 108      Jiji   23
# 131      Judy   18
# 170    Jalila   33
# 191      Judy   31
# 231    Johana   15
# 285      Jiji   17
# 291    Jalila   32
# 329      Judy   20
# 333   Jasmina   21
# 351      Judy   18
# 363    Jalila   21
# 370    Jalila   26
# 374      Judy   32
# 382      Jiji   28
# 393      Judy   31
# 395   Jasmina   18
# 409      Jala   36
# 452    Jalila   17
# 475      Jala   19
# 504      Judy   31
# 509    Jalila   23
# 572      Jiji   34
# ...       ...  ...
# 9498     Jala   20
# 9501  Jasmina   32
# 9507  Jasmina   17
# 9534     Judy   34
# 9542   Jalila   29
# 9545     Judy   34
# 9569  Jasmina   18
# 9605   Jalila   18
# 9673     Jiji   35
# 9709   Johana   23
# 9720     Jiji   15
# 9742  Jawaher   35
# 9743   Jalila   27
# 9746   Johana   29
# 9749  Jawaher   26
# ...
