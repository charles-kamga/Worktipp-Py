# %%
for i in 'Hello world':
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
'Hello world'[::-1]
# Out:
# 'dlrow olleH'

# %%
print("Hello world")
print('Hello world')
# Out:
# Hello world
# Hello world

# %%
word = 'Hello world'

# %%
word[0]
# Out:
# 'H'

# %%
word[0] ='Y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ee2bbe3d2b38> in <module>
# ----> 1 word[0] ='Y'
#
# TypeError: 'str' object does not support item assignment

# %%
word = word + ' from SmartnSkilled'

# %%
word = 'Hello world'

# %%
id(word)
# Out:
# 1863710080368

# %%
word = word + ' from SmartnSkilled'

# %%
id(word)
# Out:
# 1863710670320

# %%
word = 'HELLO WORLD'

# %%
word.lower()
# Out:
# 'hello world'

# %%
'hello world'.upper()
# Out:
# 'HELLO WORLD'

# %%
'hello world'.capitalize()
# Out:
# 'Hello world'

# %%
'hello world'.title()
# Out:
# 'Hello World'

# %%
'     hello world      '.strip()
# Out:
# 'hello world'

# %%
'     hello world      '.lstrip()
# Out:
# 'hello world      '

# %%
'     hello world      '.rstrip()
# Out:
# '     hello world'

# %%
'1234567a'.isalnum()
# Out:
# True

# %%
'1234567a%'.isalnum()
# Out:
# False

# %%
'1234567a'.isdigit()
# Out:
# False

# %%
'1234567'.isdigit()
# Out:
# True

# %%
'Hello World'.isupper()
# Out:
# False

# %%
'HELLO WORLD'.isupper()
# Out:
# True

# %%
'HELLO WORLD'.islower()
# Out:
# False

# %%
word = 'Hello   World  '

# %%
word.isspace()
# Out:
# False

# %%
'Hello World'.endswith('ld')
# Out:
# True

# %%
'Hello World'.endswith('d')
# Out:
# True

# %%
nom = 'Béchir'
prénom ='Béjaoui'
age = 40 

présentation = f"Mon nom est {nom} mon prénom est {prénom} et mon age est {age}"

# %%
présentation
# Out:
# 'Mon nom est Béchir mon prénom est Béjaoui et mon age est 40'

# %%
présentation = 'Mon nom est %s, mon prénom est %s et mon age est %i'%(nom,prénom,age)

# %%
présentation
# Out:
# 'Mon nom est Béchir, mon prénom est Béjaoui et mon age est 40'

# %%
'Mon nom est {0}, mon prénom est {1} et mon age est {2}'.format(nom,prénom,age)
# Out:
# 'Mon nom est Béchir, mon prénom est Béjaoui et mon age est 40'
