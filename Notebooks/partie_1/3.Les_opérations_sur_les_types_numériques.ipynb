# %% [markdown]
# # Conversions des types numériques

# %% [markdown]
# On utilise les fonctions:<Br>
# 1. int()<Br>
# 2. long()<Br>
# 3. float()<Br>
# 4. complex()<Br>
#    Pour la conversion entre types numériques

# %%
from math import pi
print(pi)
print(int(pi))
# Out:
# 3.141592653589793
# 3

# %%
complex(5)
# Out:
# (5+0j)

# %%
int(2 + 2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d6c76d7b574a> in <module>
# ----> 1 int(2 + 2j)
#
# TypeError: can't convert complex to int

# %% [markdown]
# ###  Les comparaisons numériques

# %%
1 == 1
# Out:
# True

# %%
2 <= 5
# Out:
# True

# %%
2 < 5
# Out:
# True

# %%
2 <> 3
# Out:
#   File "<ipython-input-62-3f09be2c34b2>", line 1
#     2 <> 3
#        ^
# SyntaxError: invalid syntax

# %%
2 != 3
# Out:
# True

# %% [markdown]
# ### Les affectations

# %%
a = 1 
a
# Out:
# 1

# %%
a = 1
a +=3
a
# Out:
# 4

# %%
a -=1
a
# Out:
# -1.0

# %%
a/=3
a
# Out:
# 0.0

# %% [markdown]
# ### La valeur aboslue

# %%
abs(-55)
# Out:
# 55

# %% [markdown]
# ### Arondissement

# %%
import math

# %%
math.ceil(5.5)
# Out:
# 6

# %%
math.floor(5.5)
# Out:
# 5

# %% [markdown]
# ### Choix aléatoire

# %% [markdown]
# #### Choix aléatoire à partir d'une liste

# %%
import random
random.choice([1,2,3,4,5,6,7,8,9])
# Out:
# 9

# %%
random.randrange(10,20,2)
# Out:
# 14

# %%
r = random.random()

# %%
print(r)
# Out:
# 0.32318846465517637

# %% [markdown]
# ### Logarithmiques

# %% [markdown]
# #### Logarithme népérien

# %%
import math
constante = math.log(math.e)
constante
# Out:
# 1.0

# %% [markdown]
# #### Logaritme à base de 10

# %%
constante = math.log10(10)
constante
# Out:
# 1.0

# %% [markdown]
# ### La trigonométrie
#
# ##### En degrées

# %%
import math
cos45 = math.cos(45)
cos45
# Out:
# 0.5253219888177297

# %%
import math
sin90 = math.sin(90)
sin90
# Out:
# 0.8939966636005579

# %% [markdown]
# ##### En radians

# %%
import math
cos45 = math.cos(math.degrees(pi/4))
cos45
# Out:
# 0.5253219888177297

# %% [markdown]
# #### Manipulations Binaires

# %%
x = 100
y = 101
print(x & y)
print(x | y)
print(x ^ y)
print(~x)
# Out:
# 100
# 101
# 1
# -101
