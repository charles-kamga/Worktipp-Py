# %% [markdown]
# # Opérations de conversions entres types numériques

# %%
On utilise 
1. int()
2. long()
3. float()
4. complex()

# %%
from math import pi
print(pi)
# Out:
# 3.141592653589793

# %%
print(int(pi))
# Out:
# 3

# %%
complex(pi)
# Out:
# (3.141592653589793+0j)

# %%
int(2 + 2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d6c76d7b574a> in <module>
# ----> 1 int(2 + 2j)
#
# TypeError: can't convert complex to int

# %% [markdown]
# ## Comparaisons numérques

# %%
1 == 1
# Out:
# True

# %%
2 <= 5
# Out:
# True

# %%
2 < 5
# Out:
# True

# %%
2 > 5
# Out:
# False

# %%
2 <> 3
# Out:
#   File "<ipython-input-9-f33a2ee7f15f>", line 1
#     2 <> 3
#        ^
# SyntaxError: invalid syntax

# %%
2 != 3
# Out:
# True

# %% [markdown]
# # La valeur absolue

# %%
abs(-55)
# Out:
# 55

# %% [markdown]
# # Arrondissment

# %%
import math

# %%
math.ceil(5.5)
# Out:
# 6

# %%
math.floor(5.5)
# Out:
# 5

# %% [markdown]
# # Le choix aléatoire d'un nombre d'une collection

# %%
import random

# %%
random.choice([1,2,3,4,5,6,7,8,9])
# Out:
# 5

# %%
random.randrange(10,20,2)
# Out:
# 12

# %%
random.random()
# Out:
# 0.6811644299094519

# %% [markdown]
# # les nombres logarithmiques

# %%
import math

# %%
math.log(math.e)
# Out:
# 1.0

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
math.log10(10)
# Out:
# 1.0

# %% [markdown]
# # La trigonométrie

# %%
math.cos(45)
# Out:
# 0.5253219888177297

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.cos(math.degrees(pi/4))
# Out:
# 0.5253219888177297

# %% [markdown]
# # Binaires

# %%
print(100 & 101)
# Out:
# 100

# %%
print(100 | 101)
# Out:
# 101

# %%
print(100 ^ 101)
# Out:
# 1

# %%
print(~100)
# Out:
# -101
