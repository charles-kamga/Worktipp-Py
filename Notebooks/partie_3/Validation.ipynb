# %%
from schema import Schema, And, Use, Optional

# %%
schema = Schema([{'name': And(str, len),
                  'age':  And(Use(int), lambda n: 18 <= n <= 99),
                   Optional('gender'): And(str, Use(str.lower),
                                          lambda s: s in ('squid', 'kid'))}])

# %%
data = [{'name': 'Sue', 'age': '28', 'gender': 'Squid'},
         {'name': 'Sam', 'age': '42'},
         {'name': 'Sacha', 'age': '20', 'gender': 'KID'}]

# %%
validated = Schema.validate(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c23b2831a790> in <module>
# ----> 1 validated = Schema.validate(data)
#
# TypeError: validate() missing 1 required positional argument: 'data'

# %%
help(Schema.validate)
# Out:
# Help on function validate in module schema:
#
# validate(self, data)

# %%
help(schema)
# Out:
# Help on module schema:
#
# NAME
#     schema
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         SchemaError
#             SchemaMissingKeyError
#             SchemaUnexpectedTypeError
#             SchemaWrongKeyError
#     builtins.object
#         And
#             Or
#         Regex
#         Schema
#             Optional
#
#     class And(builtins.object)
#      |  And(*args, **kw)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, *args, **kw)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  validate(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Optional(Schema)
#      |  Optional(*args, **kwargs)
#      |
#      |  Marker for an optional part of Schema.
#      |
#      |  Method resolution order:
#      |      Optional
#      |      Schema
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from Schema:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  validate(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from Schema:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Or(And)
#      |  Or(*args, **kw)
#      |
#      |  Method resolution order:
#      |      Or
#      |      And
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  validate(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from And:
#      |
#      |  __init__(self, *args, **kw)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from And:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Regex(builtins.object)
#      |  Regex(pattern_str, flags=0, error=None)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, pattern_str, flags=0, error=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  validate(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  NAMES = ['re.ASCII', 're.DEBUG', 're.VERBOSE', 're.UNICODE', 're.DOTAL...
#
#     class Schema(builtins.object)
#      |  Schema(schema, error=None, ignore_extra_keys=False)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, schema, error=None, ignore_extra_keys=False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  validate(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class SchemaError(builtins.Exception)
#      |  SchemaError(autos, errors)
#      |
#      |  Error during Schema validation.
#      |
#      |  Method resolution order:
#      |      SchemaError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, autos, errors)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  code
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class SchemaMissingKeyError(SchemaError)
#      |  SchemaMissingKeyError(autos, errors)
#      |
#      |  Error during Schema validation.
#      |
#      |  Method resolution order:
#      |      SchemaMissingKeyError
#      |      SchemaError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods inherited from SchemaError:
#      |
#      |  __init__(self, autos, errors)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from SchemaError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  code
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class SchemaUnexpectedTypeError(SchemaError)
#      |  SchemaUnexpectedTypeError(autos, errors)
#      |
#      |  Error during Schema validation.
#      |
#      |  Method resolution order:
#      |      SchemaUnexpectedTypeError
#      |      SchemaError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods inherited from SchemaError:
#      |
#      |  __init__(self, autos, errors)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from SchemaError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  code
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class SchemaWrongKeyError(SchemaError)
#      |  SchemaWrongKeyError(autos, errors)
#      |
#      |  Error during Schema validation.
#      |
#      |  Method resolution order:
#      |      SchemaWrongKeyError
#      |      SchemaError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods inherited from SchemaError:
#      |
#      |  __init__(self, autos, errors)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from SchemaError:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  code
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.Exception:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
# DATA
#     __all__ = ['Schema', 'And', 'Or', 'Regex', 'Optional', 'SchemaError', ...
#
# VERSION
#     0.6.2
#
# FILE
#     c:\users\bechir\miniconda3\lib\site-packages\schema-0.6.2-py3.7.egg\schema.py
