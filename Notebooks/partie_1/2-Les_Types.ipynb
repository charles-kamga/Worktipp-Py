# %% [markdown]
# # Les types

# %% [markdown]
# ## 1. Les types simples

# %% [markdown]
# 1. Les entiers & longs (numérique) exemple 1 2 88888888
# 2. Les flottans (numérique) exemple 1.41421356237 3.14159265359
# 3. Les décimaux(numérique) exemple  2.2 1.1 1.0
# 3. Les booléans (binaires) exemple True ou False
# 4. Les chaines (Les caractères) exmples  "Hello world" 'Hello World'

# %% [markdown]
# ## 2.Les types composés

# %% [markdown]
# ### Les collections

# %% [markdown]
# 1. Les listes
# 2. Les tuples
# 3. Les dictionaires
# 4. Les tableaux (Unidimensionels et Multidimensionels)

# %% [markdown]
# ### Les autres types composés

# %% [markdown]
# Exemple:
#
# 1. Les nombres complexes
# 2. Les matrices (Cas spécial de tableaux)
#
# Les classes:  (Conteneurs de varaibles et de méthodes)

# %%
print(type(int))
# Out:
# <class 'type'>
