# %% [markdown]
# # Opérations arithmétiques de base

# %%
1 + 1
# Out:
# 2

# %%
1+1+1+1
# Out:
# 4

# %%
4 - 2
# Out:
# 2

# %%
4 * 2
# Out:
# 8

# %%
4 /2
# Out:
# 2.0

# %%
4 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-87ac9c94a8c2> in <module>
# ----> 1 4 / 0
#
# ZeroDivisionError: division by zero

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
3 * 3 + 1
# Out:
# 10

# %%
2 ** 3
# Out:
# 8

# %%
1 + 2.0
# Out:
# 3.0

# %%
2.55 + 1
# Out:
# 3.55

# %%
int(2.55 + 1)
# Out:
# 3

# %%
"2" +  1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-1fa31063357b> in <module>
# ----> 1 "2" +  1
#
# TypeError: can only concatenate str (not "int") to str

# %%
int("2") + 1
# Out:
# 3

# %%
1000 - 100/2*2**2
# Out:
# 800.0

# %%
100/2
# Out:
# 50.0

# %%
2**2
# Out:
# 4

# %%
50*2
# Out:
# 100
