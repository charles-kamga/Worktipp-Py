# %%
print("Hello ICT !")
# Out:
# Hello ICT !

# %% [markdown]
# # Mon premier notebook

# %% [markdown]
# Dans ce code je vais :
#     - Faire un Hello world;
#     - Ecouter le prof;

# %%
2+True
# Out:
# 3

# %%
2*False
# Out:
# 0

# %% [markdown]
# On peut faire la conversion d'un entier en caractere, grace à :

# %%
a = '2240'
print(a + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 a = '2240'
# ----> 2 print(a + 1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
b = int(a)
print(b + 1)
# Out:
# 2241

# %% [markdown]
# Pour l'in verse c'est pareil, si on veut quitter d'un entier pour un caractere...

# %%
prenom = 'paul'
nom = 'Bissect'
type(prenom)
# Out:
# str

# %%
type(nom)
# Out:
# str

# %%
a = prenom
type(a)
# Out:
# str

# %%
id(a)
# Out:
# 140345656284848

# %%
id(prenom)
# Out:
# 140345656284848

# %% [markdown]
# Quand on a fait a = prenom, prenom a aussi pris l'adresse de a

# %%
b = 'Bissect'
id(b)
# Out:
# 140345656287440

# %%
id(nom)
# Out:
# 140345656287440

# %%
b == nom
# Out:
# True

# %%
b is nom
# Out:
# True

# %%
a = 'jean'
print(a)
# Out:
# jean

# %%
print(prenom)
# Out:
# paul

# %%
id(a)
# Out:
# 140345656287872

# %%
id(prenom)
# Out:
# 140345656284848

# %%
print(id(b))
# Out:
# 140345656287440

# %%
a=b=c= 15

# %%
print(a)
print(b)
print(c)
# Out:
# 15
# 15
# 15

# %%
id(a)
id(b)
id(c)
# Out:
# 10738832

# %%
print(id(a))
print(id(b))
print(id(c))
# Out:
# 10738832
# 10738832
# 10738832

# %%
a,b,c = 'ICT'

# %%
print(a)
print(b)
print(c)
# Out:
# I
# C
# T
# f

# %%
a,b,c = 'jean claude van dame'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 a,b,c = 'jean claude van dame'
#
# ValueError: too many values to unpack (expected 3)

# %%
a,b,*c = (1,2,3,4,5,6)
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# [3, 4, 5, 6]

# %%
a,*b,c = (1,2,3,4,5,6)
print(a)
print(b)
print(c)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
type(b)
# Out:
# list

# %%
age = input("saissez votre age : ")
print(age)
# Out:
# saissez votre age : 40
# 40
