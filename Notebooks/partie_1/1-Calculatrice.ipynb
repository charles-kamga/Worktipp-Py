# %% [markdown]
# # Python calculatrice

# %% [markdown]
# ## Opérations de calcul

# %%
1 + 1
# Out:
# 2

# %%
1 - 1
# Out:
# 0

# %% [markdown]
# #### Multiplication

# %%
2*2
# Out:
# 4

# %% [markdown]
# #### Division

# %%
10/2
# Out:
# 5.0

# %% [raw]
# Remarque: Le résultat est réel dans ce cas

# %%
10//2
# Out:
# 5

# %% [raw]
# Maintenan le résultat est entier

# %%
10//0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-11-adb5753def1b> in <module>
# ----> 1 10//0
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# #### Puissance

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# #### Modulo %

# %%
8 % 3
# Out:
# 2

# %% [raw]
# Comment ça se fait  8 = 2*3 = 6 + 2 = 8 donc 2 est le reste

# %% [raw]
# La conversion implicite n'existe pas sous python

# %%
print("2" +  3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f2b926921261> in <module>
# ----> 1 print("2" +  3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(int("2") + 3)
# Out:
# 5

# %% [markdown]
# # La précédence des opérateurs

# %% [raw]
# Il faut faire attention au combinaisons d'expressions

# %%
1000 - 100/2*2**2
# Out:
# 800.0

# %%
100/2
# Out:
# 50.0

# %%
2**2
# Out:
# 4

# %%
50*4
# Out:
# 200

# %%
1000-200
# Out:
# 800

# %%
(1000 - 100)/2*2**2
# Out:
# 1800.0

# %% [markdown]
# Voici un tableau qui arrange les opérateurs selon les priorités de chacun

# %%
# %%html
#
# <table border="1">
# 	<caption>Operator precedence rule in Python</caption>
# 	<tbody>
# 		<tr>
# 			<th scope="col" width="246">Operateurs</th>
# 			<th scope="col" width="315">Fonction assurée</th>
# 		</tr>
# 		<tr>
# 			<td align="center">()</td>
# 			<td align="center">Parentheses</td>
# 		</tr>
# 		<tr>
# 			<td align="center">**</td>
# 			<td align="center">Exposant</td>
# 		</tr>
# 		<tr>
# 			<td align="center">+x, -x, ~x</td>
# 			<td align="center">Unary plus, Unary minus, Bitwise NOT</td>
# 		</tr>
# 		<tr>
# 			<td align="center">*, /, //, %</td>
# 			<td align="center">Multiplication, Division, Floor division, Modulus</td>
# 		</tr>
# 		<tr>
# 			<td align="center">+, -</td>
# 			<td align="center">Addition, Subtraction</td>
# 		</tr>
# 		<tr>
# 			<td align="center">&lt;&lt;, &gt;&gt;</td>
# 			<td align="center">Bitwise shift operators</td>
# 		</tr>
# 		<tr>
# 			<td align="center">&amp;</td>
# 			<td align="center">Bitwise AND</td>
# 		</tr>
# 		<tr>
# 			<td align="center">^</td>
# 			<td align="center">Bitwise XOR</td>
# 		</tr>
# 		<tr>
# 			<td align="center">|</td>
# 			<td align="center">Bitwise OR</td>
# 		</tr>
# 		<tr>
# 			<td align="center">==, !=, &gt;, &gt;=, &lt;, &lt;=, is, is not, in, not in</td>
# 			<td align="center">Comparisions, Identity, Membership operators</td>
# 		</tr>
# 		<tr>
# 			<td align="center">not</td>
# 			<td align="center">Logical NOT</td>
# 		</tr>
# 		<tr>
# 			<td align="center">and</td>
# 			<td align="center">Logical AND</td>
# 		</tr>
# 		<tr>
# 			<td align="center">or</td>
# 			<td align="center">Logical OR</td>
# 		</tr>
# 	</tbody>
# </table>
# Out:
# <table border="1">
# 	<caption>Operator precedence rule in Python</caption>
# 	<tbody>
# 		<tr>
# 			<th scope="col" width="246">Operateurs</th>
# 			<th scope="col" width="315">Fonction assurée</th>
# 		</tr>
# 		<tr>
# 			<td align="center">()</td>
# 			<td align="center">Parentheses</td>
# 		</tr>
# 		<tr>
# 			<td align="center">**</td>
# 			<td align="center">Exposant</td>
# 		</tr>
# 		<tr>
# 			<td align="center">+x, -x, ~x</td>
# 			<td align="center">Unary plus, Unary minus, Bitwise NOT</td>
# 		</tr>
# 		<tr>
# 			<td align="center">*, /, //, %</td>
# 			<td align="center">Multiplication, Division, Floor division, Modulus</td>
# 		</tr>
# 		<tr>
# 			<td align="center">+, -</td>
# 			<td align="center">Addition, Subtraction</td>
# 		</tr>
# 		<tr>
# 			<td align="center">&lt;&lt;, &gt;&gt;</td>
# 			<td align="center">Bitwise shift operators</td>
# 		</tr>
# 		<tr>
# 			<td align="center">&amp;</td>
# 			<td align="center">Bitwise AND</td>
# 		</tr>
# 		<tr>
# ...

# %% [markdown]
# Les opérateurs non associatifs

# %%
1 < 2 < 3
# Out:
# True

# %%
(1 < 2) < 3
# Out:
# True

# %%
1 < (2 < 3)
# Out:
# False

# %%
1<2
# Out:
# True

# %%
2<-1
# Out:
# False

# %%
1<2<-1
# Out:
# False
